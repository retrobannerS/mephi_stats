# %%
import numpy as np         # библиотека для матриц и математики
import pandas as pd        # библиотека для работы с табличками
from scipy import stats    # модуль для работы со статистикой

# библиотеки для визуализации
import matplotlib.pyplot as plt
import seaborn as sns

import math

plt.style.use('ggplot')    # стиль графиков

# %%
# №19.157

n = 16
sigma = 4
x_mean = 20 # - случайная величина, для каждой выборки разное
#m - ? мат ожидание, не случайная величина
#1 - alpha = 0.9
alpha = 0.1
u_095 = 1.645

a = x_mean - sigma/math.sqrt(n) * u_095
b = x_mean + sigma/math.sqrt(n) * u_095
a, b # доверительный интервал
# Out:
# (18.355, 21.645)

# %%
# №19.159
# Распрделение Стьюдента, среднееквадратичное отклонение по выборке известно
n = 9
s = 3
x_mean = 30 # - случайная величина, для каждой выборки разное
#m - ? мат ожидание, не случайная величина
#1 - alpha = 0.9
alpha = 0.1
u_095 = 1.86

a = x_mean - s/math.sqrt(n) * u_095
b = x_mean + s/math.sqrt(n) * u_095
a, b # доверительный интервал
# Out:
# (28.14, 31.86)

# %%
# №19.201в
