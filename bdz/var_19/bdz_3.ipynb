# %% [markdown]
# # БДЗ третий раздел

# %%
import scipy.stats as sps
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.pyplot as plt
from array import array
import numpy as np
import pandas as pd

# %% [markdown]
# ### 3.1

# %%
X = pd.read_excel(open('data_matstat_K5.xls', 'rb'), sheet_name='B - bodyfat')['B8'].to_numpy()
print(len(X))
# Out:
# 252

# %%
m = [70, 70.5, 71]
print(X.mean())
for m0 in m:
    print(" T-test : The z-statistic is %.3f and the p-value is %.3f." % sps.ttest_1samp(X, m0))
# Out:
# 70.14880952380952
#  T-test : The z-statistic is 0.645 and the p-value is 0.520.
#  T-test : The z-statistic is -1.522 and the p-value is 0.129.
#  T-test : The z-statistic is -3.689 and the p-value is 0.000.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 3.2

# %%
sigma = [3.6, 3.4, 4]
print(X.std())
for sigma0 in sigma:
    z = X.var() * (n-1) / sigma0**(2)
    p_value = 2*min([sps.chi2.cdf(z, n - 1), 1 - sps.chi2.cdf(z, n - 1)]) 
    print(" chi2-test : The z-statistic is %.3f and the p-value is %.3f." % (z,  p_value))
# Out:
# 3.655580992440224
#  chi2-test : The z-statistic is 258.810 and the p-value is 0.708.
#  chi2-test : The z-statistic is 290.154 and the p-value is 0.090.
#  chi2-test : The z-statistic is 209.636 and the p-value is 0.054.

# %% [markdown]
# ### 3.3

# %%
X = pd.read_excel(open('data_matstat_K5.xls', 'rb'), sheet_name='C - plasma')['C11'].to_numpy()
Y = pd.read_excel(open('data_matstat_K5.xls', 'rb'), sheet_name='C - plasma')['C12'].to_numpy()

n1 = len(X)
n2 = len(Y)
print(n1, n2)
# Out:
# 315 315

# %%
print(X.mean(), Y.mean())
print(" 2-sample t-test : The z-statistic is %.3f and the p-value is %.3f." % sps.ttest_ind(X, Y))
# Out:
# 2185.6031746031745 832.7142857142857
#  2-sample t-test : The z-statistic is 15.127 and the p-value is 0.000.

# %% [markdown]
# ### 3.4

# %%
z = X.var() / Y.var()
print(" 2-sample f-test \ m : The z-statistic is %.3f and the p-value is %.3f." % (z, 2*min([sps.f.cdf(z, n1 -1 , n2-1), 1 - sps.f.cdf(z, n1-1, n2-1)])))
# Out:
#  2-sample f-test \ m : The z-statistic is 6.256 and the p-value is 0.000.
